# %%
import os

def folder_has_any_file(folder_path):
    return any(
        os.path.isfile(os.path.join(folder_path, f)) and not f.startswith(".")
        for f in os.listdir(folder_path)
    )

folder_path = "../../docs"
if folder_has_any_file("../../docs"):
    print("yes")
else:
    print("no")
# Out:
# no

# %%
import os
import sys
from langchain_openai import ChatOpenAI
sys.path.append('../..')
from langchain_mongodb import MongoDBAtlasVectorSearch
from pymongo import MongoClient
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

from service.chatbot.langchain.embedding_langchain import embedding
from service.chatbot.langchain.generating_langchain import generate
from service.chatbot.langchain.retrieving_langchain import retrieve

from langchain_openai import OpenAIEmbeddings

# %%
client = MongoClient(os.environ["MONGODB_ATLAS_CLUSTER_URI"])

db = os.environ["DB_NAME"]
collection_name = os.environ["COLLECTION_NAME"]
search_index = os.environ["ATLAS_VECTOR_SEARCH_INDEX_NAME"]

collection = client[db][collection_name]


llm = ChatOpenAI(
        base_url=os.environ["AZURE_OPENAI_ENDPOINT"],
        model=os.environ["AZURE_OPENAI_COMP_DEPLOYMENT_NAME"],
        api_key=os.environ["AZURE_OPENAI_API_VERSION"]
    )


embedder = OpenAIEmbeddings(
    model="azure-text-embedding-3-large",
    api_key=os.environ["OPENAI_API_KEY"],
    base_url=os.environ['AZURE_OPENAI_ENDPOINT']
)
vectorstore_db = MongoDBAtlasVectorSearch(
            collection=collection,
            embedding=embedder,  # same embedding model used when saving
            index_name=search_index,
            relevance_score_fn="cosine"
        )

# %%
vectorstore_db.similarity_search("The primary goal of this project is to write, test and complete a c program which uses functions")
# Out:
# [Document(id='0', metadata={'_id': '0', 'producer': 'pdfTeX-1.40.19', 'creator': 'LaTeX with hyperref package', 'creationdate': '2025-02-04T14:24:49-05:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2025-02-04T14:24:49-05:00', 'trapped': '/False', 'ptex.fullbanner': 'This is MiKTeX-pdfTeX 2.9.6642 (1.40.19)', 'source': '../../docs/Lab03_315.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'start_index': 0}, page_content='CIT315 Lab3\nLab3 - CIT315\nGoals\nThe primary goal of this project is to write, test and complete a c program which uses functions\nand recursion. It is critical that you know how to program and use recursion. While you are given\nthe code for some of these functions, make sure you know how the functions execute! There will be\nsome functions that you must write from scratch. All functions will be called by a numbered user\nmenu, prompting the user for the correct inputs for each one. Then, you will print the output in\na neatly formatted and understandable manner. The menu must ask the user if they want to run\nmore functions and also ask them if they want to quit the program, and act accordingly.\nSpeciﬁcations\nFor each of these, write a simple function. In some cases the code is given to you. Just place it in\ncontext of a program. You will have at minimum 4 functions, in your program. The main function\nand the 3 functions you will write. You must use function prototypes!Then, create a basic'),
#  Document(id='685a501336b3cef4c25f3e12', metadata={'_id': '685a501336b3cef4c25f3e12', 'producer': 'pdfTeX-1.40.19', 'creator': 'LaTeX with hyperref package', 'creationdate': '2025-02-04T14:24:49-05:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2025-02-04T14:24:49-05:00', 'trapped': '/False', 'ptex.fullbanner': 'This is MiKTeX-pdfTeX 2.9.6642 (1.40.19)', 'source': '../../docs/Lab03_315.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'start_index': 0}, page_content='CIT315 Lab3\nLab3 - CIT315\nGoals\nThe primary goal of this project is to write, test and complete a c program which uses functions\nand recursion. It is critical that you know how to program and use recursion. While you are given\nthe code for some of these functions, make sure you know how the functions execute! There will be\nsome functions that you must write from scratch. All functions will be called by a numbered user\nmenu, prompting the user for the correct inputs for each one. Then, you will print the output in\na neatly formatted and understandable manner. The menu must ask the user if they want to run\nmore functions and also ask them if they want to quit the program, and act accordingly.\nSpeciﬁcations\nFor each of these, write a simple function. In some cases the code is given to you. Just place it in\ncontext of a program. You will have at minimum 4 functions, in your program. The main function\nand the 3 functions you will write. You must use function prototypes!Then, create a basic'),
#  Document(id='685a501336b3cef4c25f3e13', metadata={'_id': '685a501336b3cef4c25f3e13', 'producer': 'pdfTeX-1.40.19', 'creator': 'LaTeX with hyperref package', 'creationdate': '2025-02-04T14:24:49-05:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2025-02-04T14:24:49-05:00', 'trapped': '/False', 'ptex.fullbanner': 'This is MiKTeX-pdfTeX 2.9.6642 (1.40.19)', 'source': '../../docs/Lab03_315.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'start_index': 815}, page_content='context of a program. You will have at minimum 4 functions, in your program. The main function\nand the 3 functions you will write. You must use function prototypes!Then, create a basic\nmenu system that allows a user to select which one of the functions they want to execute. Once\nthe user makes their choice, the program must ask them for the correct parameters. After the\nparameters are entered, the program will execute and print the results to to command line. Each\nfunction must be properly formatted, with a prototype.\nWhen the program is ﬁnished, return the number of functions that were executed in your\nprogram to the operating system. For example, if you executed all 3 functions, the return would\nbe 3. If you executed all of them two times, the return value would be 6.\nFunction 1 - Factorials\nTask: Write a function in your C program based on the code given below.\nThe factorial function is an example of direct recursion and is deﬁned by:\nn! =\n{\n1 ifn = 0\nn(n − 1)! if n >0'),
#  Document(id='1', metadata={'_id': '1', 'producer': 'pdfTeX-1.40.19', 'creator': 'LaTeX with hyperref package', 'creationdate': '2025-02-04T14:24:49-05:00', 'author': '', 'title': '', 'subject': '', 'keywords': '', 'moddate': '2025-02-04T14:24:49-05:00', 'trapped': '/False', 'ptex.fullbanner': 'This is MiKTeX-pdfTeX 2.9.6642 (1.40.19)', 'source': '../../docs/Lab03_315.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1', 'start_index': 815}, page_content='context of a program. You will have at minimum 4 functions, in your program. The main function\nand the 3 functions you will write. You must use function prototypes!Then, create a basic\nmenu system that allows a user to select which one of the functions they want to execute. Once\nthe user makes their choice, the program must ask them for the correct parameters. After the\nparameters are entered, the program will execute and print the results to to command line. Each\nfunction must be properly formatted, with a prototype.\nWhen the program is ﬁnished, return the number of functions that were executed in your\nprogram to the operating system. For example, if you executed all 3 functions, the return would\nbe 3. If you executed all of them two times, the return value would be 6.\nFunction 1 - Factorials\nTask: Write a function in your C program based on the code given below.\nThe factorial function is an example of direct recursion and is deﬁned by:\nn! =\n{\n1 ifn = 0\nn(n − 1)! if n >0')]
